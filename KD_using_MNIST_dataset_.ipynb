# %% [markdown]
# <a href="https://colab.research.google.com/github/LuBly/Knowledge_Distillation/blob/main/KD_using_MNIST_dataset_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 필요한 라이브러리를 import

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import torchvision.models as models
from torch.utils.data import DataLoader
import time
import os
import copy
from torchvision.transforms.functional import to_pil_image
import matplotlib.pyplot as plt
# %matplotlib inline

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# Loading MNIST dataset
#
# Mnist dataset을 불러온다.

# %%
# make directorch to save dataset
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSerror:
        print('Error')
createFolder('./data')

# %%
# define transformation
ds_transform = transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,),(0.3081,))
])

# %%
# load MNIST dataset
train_ds = datasets.MNIST('/content/data',train=True, download=True, transform=ds_transform)
val_ds = datasets.MNIST('/content/data',train=False, download=True, transform=ds_transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /content/data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting /content/data/MNIST/raw/train-images-idx3-ubyte.gz to /content/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /content/data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting /content/data/MNIST/raw/train-labels-idx1-ubyte.gz to /content/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /content/data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting /content/data/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /content/data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting /content/data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/data/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %% [markdown]
# 데이터 로더를 생성

# %%
# define data loader
train_dl = DataLoader(train_ds, batch_size=64, shuffle=True)
val_dl = DataLoader(val_ds, batch_size = 128, shuffle=True)

# %% [markdown]
# 샘플 이미지 확인

# %%
# check sample image
for x, y in train_dl:
    print(x.shape, y.shape)
    break

num = 4
img = x[:num]

plt.figure(figsize=(15,15))
for i in range(num):
    plt.subplot(1,num+1,i+1)
    plt.imshow(to_pil_image(0.1307*img[i]+0.3081), cmap='gray')
# Out:
# torch.Size([64, 1, 28, 28]) torch.Size([64])

# %% [markdown]
# Readme의 Soft Lable 에서 다뤘듯이
#
# 각각의 data가 가지고 있는 특징들에 대한 확률을 토대로 labeling을 진행한다.

# %% [markdown]
# Knowledge Distillation을 하기 위해 Soft Label을 얻기 위한
#
# teacher model을 먼저 만들고 학습 시킨다.

# %% [markdown]
# #**Define Teacher model**

# %%
class Teacher(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, 1200)
        self.bn1 = nn.BatchNorm1d(1200)
        self.fc2 = nn.Linear(1200,1200)
        self.bn2 = nn.BatchNorm1d(1200)
        self.fc3 = nn.Linear(1200, 10)
    
    def forward(self,x):
        x = x.view(-1, 28*28)
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.dropout(x,p=0.8)
        x = F.relu(self.bn2(self.fc2(x)))
        x = F.dropout(x,p=0.8)
        x = self.fc3(x)
        return x

# %%
# check
x = torch.randn(16,1,28,28).to(device)
teacher = Teacher().to(device)
output = teacher(x)
print(output.shape)
# Out:
# torch.Size([16, 10])

# %% [markdown]
# 가중치를 초기화 해준다.

# %%
# weight initialization
def initialize_weights(model):
    classname = model.__class__.__name__
    # fc layer
    if classname.find('Linear') != -1:
        nn.init.normal_(model.weight.data, 0.0, 0.02)
        nn.init.constant_(model.bias.data, 0)
    # batchnorm
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(model.weight.data, 1.0, 0.02)
        nn.init.constant_(model.bias.data, 0)

teacher.apply(initialize_weights);

# %% [markdown]
# Teacher model 학습

# %%
# loss function
loss_func = nn.CrossEntropyLoss()

# optimizer
opt = optim.Adam(teacher.parameters())

# lr scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.1, patience=10)

# %%
# get current lr
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']


# calculate the metric per mini-batch
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects


# calculate the loss per mini-batch
def loss_batch(loss_func, output, target, opt=None):
    loss_b = loss_func(output, target)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss_b.backward()
        opt.step()
    
    return loss_b.item(), metric_b


# calculate the loss per epochs
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output = model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b
        
        if metric_b is not None:
            running_metric += metric_b

        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data
    return loss, metric


# function to start training
def train_val(model, params):
    num_epochs=params['num_epochs']
    loss_func=params['loss_func']
    opt=params['optimizer']
    train_dl=params['train_dl']
    val_dl=params['val_dl']
    sanity_check=params['sanity_check']
    lr_scheduler=params['lr_scheduler']
    path2weights=params['path2weights']

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    best_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    start_time = time.time()

    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr= {}'.format(epoch, num_epochs-1, current_lr))

        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)
        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), path2weights)
            print('Copied best model weights!')

        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print('Loading best model weights!')
            model.load_state_dict(best_model_wts)

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
# set hyper parameters
params_train = {
    'num_epochs':30,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_dl,
    'val_dl':val_dl,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler,
    'path2weights':'./models/teacher_weights.pt',
}

createFolder('./models')

# %% [markdown]
# 30 epoch로 학습

# %% [markdown]
# #**Epoch란?**
#
# ![image.png](data:image/png;base64,...)
#
# -> Epoch : 인공 신경망에서 전체 데이터 셋에 대해
#
# forward pass/ backward pass 과정을 거친 것을 말한다.
#
# 즉, 전체 데이터 셋에 대해 한번 학습을 완료한 상태.
#
# -> Batch size는 한번의 batch마다 주는 데이터 샘플의 size.

# %%
teacher, loss_hist, metric_hist = train_val(teacher, params_train)
# Out:
# Epoch 0/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.007325, val loss: 0.002290, accuracy: 91.31, time: 0.3648 min
# ----------
# Epoch 1/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.004867, val loss: 0.002051, accuracy: 91.77, time: 0.7281 min
# ----------
# Epoch 2/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.004191, val loss: 0.001751, accuracy: 93.26, time: 1.0913 min
# ----------
# Epoch 3/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.003794, val loss: 0.001687, accuracy: 93.35, time: 1.4558 min
# ----------
# Epoch 4/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.003552, val loss: 0.001589, accuracy: 93.95, time: 1.8172 min
# ----------
# Epoch 5/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.003257, val loss: 0.001494, accuracy: 94.17, time: 2.1807 min
# ----------
# Epoch 6/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.003144, val loss: 0.001428, accuracy: 94.79, time: 2.5417 min
# ----------
# Epoch 7/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.002965, val loss: 0.001376, accuracy: 94.90, time: 2.9081 min
# ----------
# Epoch 8/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.002822, val loss: 0.001347, accuracy: 94.90, time: 3.2783 min
# ----------
# Epoch 9/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.002730, val loss: 0.001230, accuracy: 95.23, time: 3.6415 min
# ----------
# Epoch 10/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.002633, val loss: 0.001227, accuracy: 95.52, time: 4.0044 min
# ----------
# Epoch 11/29, current lr= 0.001
# train loss: 0.002558, val loss: 0.001232, accuracy: 95.56, time: 4.3671 min
# ----------
# Epoch 12/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.002452, val loss: 0.001134, accuracy: 95.54, time: 4.7293 min
# ----------
# Epoch 13/29, current lr= 0.001
# train loss: 0.002374, val loss: 0.001206, accuracy: 95.61, time: 5.0925 min
# ----------
# Epoch 14/29, current lr= 0.001
# train loss: 0.002280, val loss: 0.001222, accuracy: 95.76, time: 5.4523 min
# ----------
# Epoch 15/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.002233, val loss: 0.001107, accuracy: 95.90, time: 5.8142 min
# ----------
# Epoch 16/29, current lr= 0.001
# train loss: 0.002131, val loss: 0.001142, accuracy: 95.68, time: 6.1750 min
# ----------
# Epoch 17/29, current lr= 0.001
# train loss: 0.002163, val loss: 0.001116, accuracy: 95.99, time: 6.5377 min
# ----------
# Epoch 18/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.002107, val loss: 0.001065, accuracy: 96.03, time: 6.8991 min
# ----------
# Epoch 19/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.002035, val loss: 0.001043, accuracy: 96.33, time: 7.2626 min
# ----------
# Epoch 20/29, current lr= 0.001
# train loss: 0.002009, val loss: 0.001100, accuracy: 96.18, time: 7.6250 min
# ----------
# Epoch 21/29, current lr= 0.001
# train loss: 0.002020, val loss: 0.001051, accuracy: 95.89, time: 7.9882 min
# ----------
# Epoch 22/29, current lr= 0.001
# train loss: 0.001869, val loss: 0.001097, accuracy: 96.18, time: 8.3546 min
# ----------
# Epoch 23/29, current lr= 0.001
# train loss: 0.001861, val loss: 0.001045, accuracy: 96.19, time: 8.7193 min
# ----------
# Epoch 24/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.001873, val loss: 0.001035, accuracy: 96.40, time: 9.0809 min
# ----------
# Epoch 25/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.001865, val loss: 0.000998, accuracy: 96.55, time: 9.4463 min
# ----------
# Epoch 26/29, current lr= 0.001
# Copied best model weights!
# train loss: 0.001793, val loss: 0.000986, accuracy: 96.31, time: 9.8086 min
# ----------
# Epoch 27/29, current lr= 0.001
# train loss: 0.001762, val loss: 0.001197, accuracy: 96.26, time: 10.1718 min
# ----------
# Epoch 28/29, current lr= 0.001
# train loss: 0.001742, val loss: 0.000991, accuracy: 96.58, time: 10.5338 min
# ----------
# Epoch 29/29, current lr= 0.001
# train loss: 0.001737, val loss: 0.001039, accuracy: 96.55, time: 10.8961 min
# ----------

# %% [markdown]
# Loss와 accuracy를 시각화.

# %%
num_epochs = params_train['num_epochs']

# Plot train-val loss
plt.title('Train-Val Loss')
plt.plot(range(1, num_epochs+1), loss_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), loss_hist['val'], label='val')
plt.ylabel('Loss')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# plot train-val accuracy
plt.title('Train-Val Accuracy')
plt.plot(range(1, num_epochs+1), metric_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), metric_hist['val'], label='val')
plt.ylabel('Accuracy')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# %% [markdown]
# Define Student model
#
# teacher model에서 학습한 지식을 사용할 student model을 정의한다.

# %%
class Student(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, 800)
        self.bn1 = nn.BatchNorm1d(800)
        self.fc2 = nn.Linear(800,800)
        self.bn2 = nn.BatchNorm1d(800)
        self.fc3 = nn.Linear(800,10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.fc3(x)
        return x

# %%
# check
x = torch.randn(16,1,28,28).to(device)
student = Student().to(device)
output = student(x)
print(output.shape)
# Out:
# torch.Size([16, 10])

# %% [markdown]
# 가중치 초기화

# %%
# weight initialization
def initialize_weights(model):
    classname = model.__class__.__name__
    # fc layer
    if classname.find('Linear') != -1:
        nn.init.normal_(model.weight.data, 0.0, 0.02)
        nn.init.constant_(model.bias.data, 0)
    # batchnorm
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(model.weight.data, 1.0, 0.02)
        nn.init.constant_(model.bias.data, 0)

student.apply(initialize_weights);

# %% [markdown]
# # **Knowledge distillation**
#
# teacher model에서 학습한 soft label을 사용하여
#
# student model을 Knowldege distillation loss로 학습
#
# ![image.png](data:image/png;base64,...)

# %%
teacher = Teacher().to(device)
# load weight
teacher.load_state_dict(torch.load('/content/models/teacher_weights.pt'))

student = Student().to(device)

# optimizer
opt = optim.Adam(student.parameters())

# %%
# knowledge distillation loss
def distillation(y, labels, teacher_scores, T, alpha):
    # distillation loss + classification loss
    # y: student
    # labels: hard label
    # teacher_scores: soft label
    return nn.KLDivLoss()(F.log_softmax(y/T), F.softmax(teacher_scores/T)) * (T*T * 2.0 + alpha) + F.cross_entropy(y,labels) * (1.-alpha)

# val loss
loss_func = nn.CrossEntropyLoss()

# %%
def distill_loss_batch(output, target, teacher_output, loss_fn=distillation, opt=opt):
    loss_b = loss_fn(output, target, teacher_output, T=20.0, alpha=0.7)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss_b.backward()
        opt.step()

    return loss_b.item(), metric_b

# %% [markdown]
# 100 epoch로 학습

# %%
num_epochs= 100

loss_history = {'train': [], 'val': []}
metric_history = {'train': [], 'val': []}

best_loss = float('inf')
start_time = time.time()

for epoch in range(num_epochs):
    current_lr = get_lr(opt)
    print('Epoch {}/{}, current lr= {}'.format(epoch, num_epochs-1, current_lr))

    # train
    student.train()

    running_loss = 0.0
    running_metric = 0.0
    len_data = len(train_dl.dataset)

    for xb, yb in train_dl:
        xb = xb.to(device)
        yb = yb.to(device)

        output = student(xb)
        teacher_output = teacher(xb).detach()
        loss_b, metric_b = distill_loss_batch(output, yb, teacher_output, loss_fn=distillation, opt=opt)
        running_loss += loss_b
        running_metric_b = metric_b
    train_loss = running_loss / len_data
    train_metric = running_metric / len_data

    loss_history['train'].append(train_loss)
    metric_history['train'].append(train_metric)

    # validation
    student.eval()
    with torch.no_grad():
        val_loss, val_metric = loss_epoch(student, loss_func, val_dl)
    loss_history['val'].append(val_loss)
    metric_history['val'].append(val_metric)


    lr_scheduler.step(val_loss)

    print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
    print('-'*10)
# Out:
# Epoch 0/99, current lr= 0.001
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   import sys
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2742: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# train loss: 0.032204, val loss: 0.000897, accuracy: 96.99, time: 0.3595 min
# ----------
# Epoch 1/99, current lr= 0.001
# train loss: 0.027833, val loss: 0.000695, accuracy: 97.45, time: 0.7192 min
# ----------
# Epoch 2/99, current lr= 0.001
# train loss: 0.027359, val loss: 0.000684, accuracy: 97.60, time: 1.0779 min
# ----------
# Epoch 3/99, current lr= 0.001
# train loss: 0.026822, val loss: 0.000595, accuracy: 97.85, time: 1.4324 min
# ----------
# Epoch 4/99, current lr= 0.001
# ----------
# Epoch 30/99, current lr= 0.001
# train loss: 0.025676, val loss: 0.000497, accuracy: 98.20, time: 11.0904 min
# ----------
# Epoch 31/99, current lr= 0.001
# train loss: 0.025893, val loss: 0.000464, accuracy: 98.28, time: 11.4462 min
# ----------
# Epoch 32/99, current lr= 0.001
# train loss: 0.025780, val loss: 0.000545, accuracy: 98.24, time: 11.7976 min
# ----------
# Epoch 33/99, current lr= 0.001
# train loss: 0.025670, val loss: 0.000490, accuracy: 98.23, time: 12.1469 min
# ----------
# Epoch 34/99, current lr= 0.001
# train loss: 0.025625, val loss: 0.000473, accuracy: 98.25, time: 12.4977 min
# ----------
# Epoch 35/99, current lr= 0.001
# train loss: 0.025656, val loss: 0.000475, accuracy: 98.25, time: 12.8462 min
# ----------
# Epoch 36/99, current lr= 0.001
# train loss: 0.025817, val loss: 0.000464, accuracy: 98.21, time: 13.2013 min
# ----------
# Epoch 37/99, current lr= 0.001
# train loss: 0.025618, val loss: 0.000487, accuracy: 98.24, time: 13.5552 min
# ----------
# Epoch 38/99, current lr= 0.001
# train loss: 0.025428, val loss: 0.000469, accuracy: 98.29, time: 13.9110 min
# ----------
# Epoch 39/99, current lr= 0.001
# train loss: 0.025483, val loss: 0.000470, accuracy: 98.20, time: 14.2740 min
# ----------
# Epoch 40/99, current lr= 0.001
# train loss: 0.025597, val loss: 0.000468, accuracy: 98.24, time: 14.6265 min
# ----------
# Epoch 41/99, current lr= 0.001
# train loss: 0.025575, val loss: 0.000462, accuracy: 98.27, time: 14.9807 min
# ----------
# Epoch 42/99, current lr= 0.001
# train loss: 0.025600, val loss: 0.000455, accuracy: 98.30, time: 15.3360 min
# ----------
# Epoch 43/99, current lr= 0.001
# train loss: 0.025589, val loss: 0.000479, accuracy: 98.29, time: 15.6949 min
# ----------
# Epoch 44/99, current lr= 0.001
# train loss: 0.025638, val loss: 0.000471, accuracy: 98.34, time: 16.0473 min
# ----------
# Epoch 45/99, current lr= 0.001
# train loss: 0.025657, val loss: 0.000474, accuracy: 98.22, time: 16.4009 min
# ----------
# Epoch 46/99, current lr= 0.001
# train loss: 0.025582, val loss: 0.000454, accuracy: 98.25, time: 16.7535 min
# ----------
# Epoch 47/99, current lr= 0.001
# train loss: 0.025669, val loss: 0.000461, accuracy: 98.36, time: 17.1063 min
# ----------
# Epoch 48/99, current lr= 0.001
# train loss: 0.025534, val loss: 0.000504, accuracy: 98.18, time: 17.4560 min
# ----------
# Epoch 49/99, current lr= 0.001
# train loss: 0.025425, val loss: 0.000442, accuracy: 98.31, time: 17.8081 min
# ----------
# Epoch 50/99, current lr= 0.001
# train loss: 0.025601, val loss: 0.000466, accuracy: 98.33, time: 18.1569 min
# ----------
# Epoch 51/99, current lr= 0.001
# train loss: 0.025529, val loss: 0.000444, accuracy: 98.38, time: 18.5098 min
# ----------
# Epoch 52/99, current lr= 0.001
# train loss: 0.025567, val loss: 0.000445, accuracy: 98.34, time: 18.8616 min
# ----------
# Epoch 53/99, current lr= 0.001
# train loss: 0.025523, val loss: 0.000454, accuracy: 98.32, time: 19.2145 min
# ----------
# Epoch 54/99, current lr= 0.001
# train loss: 0.025511, val loss: 0.000461, accuracy: 98.25, time: 19.5666 min
# ----------
# Epoch 80/99, current lr= 0.001
# train loss: 0.025491, val loss: 0.000446, accuracy: 98.34, time: 28.8270 min
# ----------
# Epoch 81/99, current lr= 0.001
# train loss: 0.025327, val loss: 0.000463, accuracy: 98.27, time: 29.1761 min
# ----------
# Epoch 82/99, current lr= 0.001
# train loss: 0.025197, val loss: 0.000449, accuracy: 98.30, time: 29.5292 min
# ----------
# Epoch 83/99, current lr= 0.001
# train loss: 0.025395, val loss: 0.000449, accuracy: 98.31, time: 29.8835 min
# ----------
# Epoch 84/99, current lr= 0.001
# train loss: 0.025327, val loss: 0.000457, accuracy: 98.31, time: 30.2372 min
# ----------
# Epoch 85/99, current lr= 0.001
# train loss: 0.025530, val loss: 0.000443, accuracy: 98.38, time: 30.5937 min
# ----------
# Epoch 86/99, current lr= 0.001
# train loss: 0.025257, val loss: 0.000473, accuracy: 98.21, time: 30.9457 min
# ----------
# Epoch 87/99, current lr= 0.001
# train loss: 0.025454, val loss: 0.000448, accuracy: 98.24, time: 31.2998 min
# ----------
# Epoch 88/99, current lr= 0.001
# train loss: 0.025471, val loss: 0.000454, accuracy: 98.22, time: 31.6570 min
# ----------
# Epoch 89/99, current lr= 0.001
# train loss: 0.025373, val loss: 0.000448, accuracy: 98.31, time: 32.0087 min
# ----------
# Epoch 90/99, current lr= 0.001
# train loss: 0.025476, val loss: 0.000455, accuracy: 98.32, time: 32.3657 min
# ----------
# Epoch 91/99, current lr= 0.001
# train loss: 0.025391, val loss: 0.000446, accuracy: 98.34, time: 32.7220 min
# ----------
# Epoch 92/99, current lr= 0.001
# train loss: 0.025406, val loss: 0.000444, accuracy: 98.33, time: 33.0751 min
# ----------
# Epoch 93/99, current lr= 0.001
# train loss: 0.025231, val loss: 0.000461, accuracy: 98.27, time: 33.4299 min
# ----------
# Epoch 94/99, current lr= 0.001
# train loss: 0.025303, val loss: 0.000444, accuracy: 98.31, time: 33.7826 min
# ----------
# Epoch 95/99, current lr= 0.001
# train loss: 0.025345, val loss: 0.000434, accuracy: 98.31, time: 34.1369 min
# ----------
# Epoch 96/99, current lr= 0.001
# train loss: 0.025486, val loss: 0.000443, accuracy: 98.34, time: 34.4929 min
# ----------
# Epoch 97/99, current lr= 0.001
# train loss: 0.025469, val loss: 0.000462, accuracy: 98.27, time: 34.8470 min
# ----------
# Epoch 98/99, current lr= 0.001
# train loss: 0.025345, val loss: 0.000460, accuracy: 98.29, time: 35.2091 min
# ----------
# Epoch 99/99, current lr= 0.001
# train loss: 0.025354, val loss: 0.000447, accuracy: 98.40, time: 35.5644 min
# ----------

# %%
num_epochs = params_train['num_epochs']
# Plot train-val loss
plt.title('Train-Val Loss')
plt.plot(range(1, num_epochs+1), loss_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), loss_hist['val'], label='val')
plt.ylabel('Loss')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# plot train-val accuracy
plt.title('Train-Val Accuracy')
plt.plot(range(1, num_epochs+1), metric_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), metric_hist['val'], label='val')
plt.ylabel('Accuracy')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# %% [markdown]
# 1200크기로 학습한 Teacher model을 통해
#
# 800크기의 Student model을 학습시켰을 때
#
# out_features: 1200
#
# ![image.png](data:image/png;base64,...)
# ----------------------------------------------------------------------------
# out_features: 800
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 대략 2프로가량의 성능 향상이 있음을 알 수 있었다.

# %% [markdown]
# Reference
#
# https://m.blog.naver.com/qbxlvnf11/221449297033
#
# https://www.slideshare.net/w0ong/ss-82372826
#
# https://deep-learning-study.tistory.com/700
#
# https://github.com/LuBly/Knowledge_Distillation/blob/main/README.md
